# %%
import pandas as pd

# %%
class PrintColors:
    """
    **** change the colors used to print
    Example of use:
    print(f'{PrintColors.BOLD} this is printed in bold  {PrintColors.RESET} comm back to normal
    {PrintColors.foreground_rgb(100,100,255)} blue fore{PrintColors.background_rgb(200,0,100)}
    changed background {PrintColors.RESET}')
    """
    RESET = '\033[0m'
    BOLD = '\033[1m'
    ITALIC = '\033[3m'
    UNDERLINE_ON = '\033[4m'
    UNDERLINE_OFF = '\033[24m'
    BLINK_SLOW = '\033[5m'
    BLINK_FAST = '\033[6m'
    BLINK_OFF = '\033[25m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    # standard colors
    RED = '\033[38;2;255;0;0m'
    BACKGROUND_RED = '\033[48;2;255;0;0m'
    LIME = '\033[38;2;0;255;0m'
    BACKGROUND_LIME = '\033[48;2;0;255;0m'
    BLUE = '\033[38;2;0;0;255m'
    BACKGROUND_BLUE = '\033[48;2;0;0;255m'
    GREEN = '\033[38;2;0;128;0m'
    BACKGROUND_GREEN = '\033[48;2;0;128;0m'
    YELLOW = '\033[38;2;255;255;0m'
    BACKGROUND_YELLOW = '\033[48;2;255;255;0m'
    MAGENTA = '\033[38;2;255;0;255m'
    BACKGROUND_MAGENTA = '\033[48;2;255;0;255m'
    CYAN = '\033[38;2;0;255;255m'
    BACKGROUND_CYAN = '\033[48;2;0;255;255m'
    GRAY = '\033[38;2;128;128;128m'
    BACKGROUND_GRAY = '\033[48;2;128;128;128m'
    ORANGE = '\033[38;2;255;94;19m'
    BACKGROUND_ORANGE = '\033[48;2;255;94;19m'
    BROWN = '\033[38;2;136;69;19m'
    BACKGROUND_BROWN = '\033[48;2;136;69;19m'

    @staticmethod
    def foreground_rgb(r, g, b):
        return f'\033[38;2;{r};{g};{b}m'

    @staticmethod
    def background_rgb(r, g, b):
        return f'\033[48;2;{r};{g};{b}m'

    @staticmethod
    def set_foreground(r, g, b):
        print(PrintColors.foreground_rgb(r, g, b))

    @staticmethod
    def set_background(r, g, b):
        print(PrintColors.background_rgb(r, g, b))

# %%
model_name='wav2vec2-large-xlsr-53-spanish'
result=f'/home/pau/stiga_asr/hugging_face_res/ESP/{model_name}/res_auto_esp.xlsx'
r=pd.read_excel(result).loc[:,['file_name','Transcripcion']]
gt=pd.read_excel('/home/pau/development_python/stiga_asr/ground_truth/Audios Stiga.xlsx',sheet_name='ESP').loc[:,['AUDIOS','CORRECIÓN']]

# %%
r['AUDIOS']=r.file_name.apply(lambda x: x[:-4])

# %%
total=pd.merge(gt,r.loc[:,['AUDIOS','Transcripcion']])

# %%
print(f'{PrintColors.BOLD}Resultados muestras modelo: {model_name}')
for i in range(total.shape[0]):
    print(f'\n{PrintColors.RESET}{PrintColors.BOLD}{PrintColors.UNDERLINE_ON}Real:{PrintColors.UNDERLINE_OFF}\n {PrintColors.BLUE}{total.iloc[i,1]}\n{PrintColors.RESET}{PrintColors.BOLD}{PrintColors.UNDERLINE_ON}Predicción:{PrintColors.UNDERLINE_OFF}\n{PrintColors.ITALIC}{PrintColors.GRAY}{total.iloc[i,2]}')
    print()
# Out:
# Resultados muestras modelo: wav2vec2-large-xlsr-53-spanish
#
# Real:
#  "Vale desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "no se me ocurre nada"
# Predicción:
# vale decer realizarnos alguna sugerencia que no se ayuda a mejorar el servicio recibido no se le ocurre nada
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "no"
# Predicción:
# desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "No, de momento ya te digo yo solo me encontrado en esta situación y como me atendieron bien que que te voy a decir no no voy a poder, no puedo decir que mal porque fue todo muy bien pues estupendo"
# Predicción:
# deje se realiza alguna suferencia que no se ayuda a mejorar el servicio recibido no de momento ya se dijo dio solo he encontrado en esta situación y como madellin bien que te voy a decir no no puedo decir quemado porque acuerdo bien por el soprendo
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "no"
# Predicción:
# este araiza nos alguna sugerencia que nos ayuda a mejorar el servicio recibido
#
#
# Real:
#  "Y desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "no"
# Predicción:
# y desea realizarnos alguna sugerencia que no se ayuda a mejorar el servicio recibido
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido, algo a comentarnos"
# "Ahora mismo no"
# "Perfecto"
# Predicción:
# destaca de unas alguna sugerencia que no se a mejorar el servicio recibido algo a confederado perfecto
#
#
# Real:
#  "De acuerdo, y desea realizar alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "no"
# Predicción:
# de acuerdo y deseas realizar algunas referencias que nos ayuda a mejorar el servicio recibido
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido"
# "no"
# Predicción:
# desea realizar una segunda suferencia que no se ayuda mejorar el servicio recibido
#
#
# Real:
#  "Desea realizar alguna sugerencia que nos ayude a mejorar el servicio recibido"
# "No la verdad me encuentro muy satisfecha"
# Predicción:
# el desea realizar algunas sugerencias que nos ayuda mejora del servicio recibido no encontró muy satisfecho
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayude a mejorar el servicio recibido"
# "No"
# Predicción:
# desea realizarnos alguna sugerencia que nos ayuda a mejorar el servicio recibido
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayude a mejorar el servicio recibido"
# "no"
# Predicción:
# le fue realizado alguna sugerencia que los sellos a mejorar el servicio recibido
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayude a mejorar el servicio recibido"
# "No"
# Predicción:
# se se realizarnos abundaujeres ya que no se ha ido mejorar el servicio recibido no
#
#
# Real:
#  "Desea realizarnos alguna sugerencia que nos ayude a mejorar el servicio recibido"
# "No no la verdad"
# Predicción:
# desea reistano según la sugerencia que uno se ayuda mejor el servicio recibido
#
#
# Real:
#  "Y desea realizarnos alguna sugerencia que nos ayude a mejorar el servicio recibido"
# "No ya esta todo bien"
# Predicción:
# y desea realizarnos alguna sugerencia que nos ayuda a mejorar servicioposiciono ivetario
#
#
# Real:
#  Cual es el motivo de su valoracion disculpe, usetd me decía
# Pues el motivo es que como usuaria a mi sinceramente me han dejado en un muy mal lugar y despues de haberme
# preocupado por solventar una situación que bueno que es problema de ellos al final el que me manden dos citas diferentes de lo mismo pues si luego despues
# de haberme preocupado por solucionarlo nadie me lo ha querido solucionar, de hecho la chica con la que hablé por telefono super desagradable osea no se puede ser mas pasota, de verdad
# Predicción:
# cual este motivo de su valoración disculpe usted decía pues el motivo este como usuaria misicamente me han dejado en muy mal lugar y después de haberme preocupado por solventar una situación que se bueno que es problema de ellos al final que manadocita diferentes de lo mismo pues que luego después de haberme preocupado para solucionarlo nadie aterido de solucionar desde láctica colabor telefono super desagradable no se puede ser más pasota es verdad
#
#
# Real:
#  Cual es el motivo de su valoracion que es lo que mas le gusta de Asepeyo señor Patrick?
# Pues la atención fue muy rapida y todo
# Predicción:
# cual es el motivo de su valoración que es lo que más le gustaría ese pelo señor patrick pues la atención fue muy rápida y todo estado municipio
#
#
# Real:
#  Valore su nivel de satisfaccion general con los servicios Asepeyo?
# Un diez, un diez
# Cual es el motivo de su valoración porque le merece este diez?
# Porque la verdad estuve muy bien atendido, en todo momento se preocuparon por mi. la verdad es que fueron super amables me
# hicieron sentir muy comodo en una situacion un poco delicada, y la verdad que lo hicieron muy rapido todo y la verdad que la
# gestion muy buena todo el rato y muy bien la verdad
# Predicción:
# abre su universalización general procedido a casero muy somatenes cues el motivo de su oración porque le merece estereporque arades muy muy entendido el conjunto se procura por vi la vedado pero super amable emitieron sentir muy cómodo en una situación un poco delicada y que lo tiene muy rápido todo y al que se la catión muy buena si todo el trato y muy narrado
#
#
# Real:
#  Y cual es el motivo de su valoración?
# Que esta muy bien, buenos profesionales y muy buena atención
# Predicción:
# i cuál es el motivo de su valoración cuestan está muy bien en buenos profesionales en muy buena atención
#
#
# Real:
#  Cual es el motivo de su valoración?
# Pues que me trataron fernomenal entonces principalmente ya te digo el medico que me atendió me explico perfectamente la lesión que tenia, todas las dudas que tenia y la verdad una calidad humana también perfecta
# Predicción:
# cual es el motivo de su evaluación pues que me trataron fenomenales doses principalmente lateromedico que me atendió me explicó perfectamente la lesión que tenía todas las dudas que tenía y la una calidad humana también perfecta
#
#
# Real:
#  Cual es el motivo de su valoración, porque esta usted satisfecha con el numero diez que es lo que le sacaría?
# Porque pues yo que se a mi me despacharon bien todo bien es que no [no entiendo]
#
# Predicción:
# cual es el motivo de su valoración porque esta sea peces con el número diez es lo que le sacaría polecam me despacharon bien todo bien es que el amor de eeproblema
#
#
# Real:
#  Cual es el motivo de su valoración de este diez?
# Bueno porque yo veo que haber atienden bien, estava todo correctamente osea veo todo correcto
# Predicción:
# y por es el motivo de su valoración despernado que yo veo que atienden bien estaba todo correctamente de todo completo
#
#
# Real:
#  Y cual es el motivo de su valoración?
# Pues satisafctorio
# Predicción:
# y cuál es el motivo de su valoración satisaturio
#
#
# Real:
#  Y nos puede indicar cual es el motivo de su valoración, porque esta satisfecho usted, esta valorado con un nueve?
# Estoy satisfecho porque tuve, con el accidente me trataban muy bien y aoarte me hicieron las pruebas que que eran oportunas sin *no entiendo* el coche
# Predicción:
# y nos puede indicar cuál es el motivo de su valoración porque está satisfecho usted está valorado con nueve potente valorado la fuerte misera roa de el oportuna potende acuerdo
#
#
# Real:
#  Cual es el motivo de su valoración porque ha indicado un ocho en su satisfacción general en los servicios de Asepeyo?
# Porque cuando me toco ir a ir a Asepeyo y de verdad que la cuando la de adminsion me dijo donde teniamos que ir
# Predicción:
# cual es el motivo de su valoración por cántica de noche su satisfacción general con los servicios de acetelño porque cuando cuando me toco iba a su pelo sigue verdadque la cuando la ambición me dijo donde teníamos que
#
#
# Real:
#  Cual es el motivo de la valoración senyora García porque valora Asepeyo con un ocho?
# Pues porque [no entiendo]
# Pero aun así esta satisfecha?
# Hombre si estoy satisfecha pero no como para un diez
# Predicción:
# feliz el motivo de la valoración señora garcía porque valora se peló con un ocho porque esperan sus logano mucho estromatitas sacose a merced satisface a asistencia pero no como para de
#
#
# Real:
#  Y cual es el motivo de su valoración con un diez señora Fernández?
# Pues las veces que ido la verdad que me han atendido muy bien, lo unico la espera que la última vez tuve que esperar bastante y por lo demas vamos todo muy limpio, todo el trato muy amable
# Predicción:
# igual es el motivo de su valoración colombia señora fernández pues latas querido la verdaguer a tenido muy bie lo único la entera que la última vez fue que esperara asante y por lo demás batolimpio todo el trato muy amable y
#
#
# Real:
#  Cual es el motivo de su valoración?
# Pues que todo funciono perfectamente
# Predicción:
# cuál es el motivo de su valoración pues que todo funcionó perfectamente
#
#
# Real:
#  Cual es el motivo de su valoración?
# Toda la atención prestada en conjunto
# Predicción:
# puedes el motivo de su valoración toda la atención pro esta en conjunto así tomo nota
#
#
# Real:
#  Cual es el motivo de su valoración?
# Porque me han atendido bien,[ehhehheh]
# El buen servicio?
# Sí buen servicio
# Predicción:
# cual es el motivo de su valoración porque mantenido de al magnate viendolo buen servicio sigo en servicio
#
#
# Real:
#  Y nos puede indicar cual es el motivo de su valoración, porque esta satisfecha?
# Porque nos atienden muy bien y normalmente nos hacen esperar poco
# Predicción:
# y dos puede indicar los motivos de su valoración porque está satisfecha por porque daños atienden muy leña y normalmente no ladinesperar poco
#
#
# Real:
#  Cual es el motivo de su valoración, porque ha indicado un diez senyor Ramirez?
# Siempre he sido muy bien atendido
# Predicción:
# cuál es el motivo de su valoración por tendi ca donde el señor ramírez siempre he sido muy bien atendido
#
#
# Real:
#  Y que seria para usted la más destacable, lo que mas le gusto?
# La atención muy personal me ha dicho y
# Sí y la rapidez
# Y la rapidez en ser atendido?
# Predicción:
# que sería para usted lo más destacable lo que más le gustóla atención muy personal me ha dicho y la rapidez muy personal y la rapidez en ser atendido
#
#
# Real:
#  Y cual es el motivo de su valoración senyora Pozuelo?
# Pues la verdad que siempre que he ido he salido, me he sentido bien ahí
# Predicción:
# igual es el motivo de su valoración sin el paselo pues la verdad que siempre querido de salido me sentido bien allí
#
#
# Real:
#  Cual es el motivo de su valoración?
# Pues por la atención, la rapidez y la profesionalidad que han demostrao
# Predicción:
# carece el motivo de su valoración pues por la atención la rapidez y la profesionalidad que demostró
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson, es decir alguna cosa que quiera añadir?
# Si
# Diganos señor Ferreiro
# Si claro
# Predicción:
# tiene usted alguna sugerencia comentario para mejorar el servicio que recibe es una especie alguna cosa que queda añadió se nos díganoseñor ferreiro
#
#
# Real:
#  Y tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# Bueno no así esta bien
# Predicción:
# y tiene usted alguna sugerencia comentario para mejorar el servicio que recibe de esto
#
#
# Real:
#  Pues piense alguna sugerencia algun comentario que recibe de Epson que me quiera indicar?
# No ninguno el servicio tecnico es muy competente
# De acuerdo
# I todo muy bien, no
# Predicción:
# position se a una suferencia un comentario para mejor ese vitocroivesson quien quiere indicar o ninguno del servicio un técnico es muy competente y todo medio
#
#
# Real:
#  Quiere añadir alguna sugerencia o comentario para mejorar el servicio tecnico de Epson?
# No, el servicio tecnico es muy bueno no, no, se puede hombre todo es mejorable pero
# Predicción:
# quiere añadir alguna sugerente comentario para mejorar el servicio del técnico de epson todo el eticotónico como bueno no no no todos mejorable pero
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# Bueno en principio lo que ya te he comentado tampoco
# Predicción:
# tiene se algunas sugerencias comentarios para mejorar el servicio que recibe de pisoneincidio no queda documentado tampoco
#
#
# Real:
#  Bueno Tiene usted alguna sugerencia o comentario para mejorar
# Nada más
# recibe Epson?
# Nada
# Y por ultimo
# Predicción:
# pues viéndose alguna sugerencia comentario para melararecibe edson polaúltimo
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# Pues no la verdad, es que ultimamente todos los [no entiendo] llegaban a tiempo, cuando llamo para algun problema lo solventan y
# Predicción:
# tiene este álbum a sujeto comentario para mejorar el servicio que recibe eso pues no la verdad es que últimamente todos los dones me llevan a tiempo cuando llamó para algún problema no los solventan y
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# No
# Predicción:
# si los haga usted alguna sugerencia comentario para mejorar este piso de hiberecho
#
#
# Real:
#  Tienes alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# No
# Predicción:
# vestimos alguna sugerencia comentario para mejor el servicio que recibe debsonno
#
#
# Real:
#  Tiene usted alguna sugerencia señor [no entiendo] o comentario para mejorar el servicio que recibe de Epson?
# No
# Predicción:
# tiene usted algunas sugerencias en el brote o comentario para mejorar el servicio que recibe de epson
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# No
# Predicción:
# tiene usted alguna surgencia comentario para mejorar el servicio que recibe
#
#
# Real:
#  Bien, tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# No ninguna porque estaba todo bien
# Predicción:
# bien tiene usted alguna sugerencia comentario para mejorar este vicio que recibe epson no ninguna tan todo bien
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# No, no en principio no
# Predicción:
# tiene este es alguna sugerencia comentario para mejorar el servicio que recibe de eso no
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# Ahora mismo no se me ocurre
# Predicción:
# tienes alguna sugerencia comentario para mejorar el servicio que recibe de esta para mi menos
#
#
# Real:
#  Y tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# Pues ahora misimo no se me ocurre nada
# Predicción:
# y cinta una experencia comentario para mejorar el servicio crece epson que nos quia indicar solo ninguno solo ocurrido
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# En principio no
# Predicción:
# tengo esta alguna sugerencia comentario para mejorar el servicio que recibe de
#
#
# Real:
#  Tiene alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# No
# Predicción:
# iene alguna sugerencia comentario para mejorar el servicio que recibe de eso no
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar el servicio que recibe de Epson?
# Al servicio tecnico se refiere solamente?
# Predicción:
# tiene usted alguna suferencia comentario para mejorar el servicio que recibe del son el servicio técnico que refiere solamente
#
#
# Real:
#  Quiere añadir algun comentario más?
# No nada más
# Predicción:
# tire añadir algún comentario más
#
#
# Real:
#  Y tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# Pues no en principio no
# Predicción:
# y tiene algunas mujeres de comentarios para mejorar nuestros servicios pues no
#
#
# Real:
#  Señor Vicente tienes alguna sugerencia o comentario para mejorar nuestro servicio?
# Pues que el servicio de asistencia en cristales es muy bueno pero en fontaneria es un autentico desastre
# Predicción:
# se vicente cines alguna sugerencia comentaria para mejorar este servicio pues que el servicio de asistencia en cristales muy bueno en fontanería de un auténtico desastre
#
#
# Real:
#  Y ahora tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# No la verdad es que ha mejorado bastante sí
# Predicción:
# y ahora tiene alguna sugerencia comentario para mejorar nuestros servicios es que ha mejorado bastante
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar nuestro servicio?
# No
# Predicción:
# tienes alguna sugerencia comentario para mejorar nuestros serviciosno
#
#
# Real:
#  Hemos acabado alguna sugerencia, algun comentario para mejorar su servicio que nos quiera hacer llegar, señor Gonzalo?
# No, no se me ocurre nada
# Predicción:
# os acabado alguna suferencia un comentario para nes gran servicio que nos quiere hacer llegar
#
#
# Real:
#  Y tiene usetd alguna sugerencia o comentario para mejorar nuestro servicio?
# Pues no, la verdad es que no puedo decir nada no tengo ninguna sugerencia
# Predicción:
# y tiene sed al una sugerencia comentario para mejorar nuestro servicio la verdad que no puedo decirlo en sugerencia
#
#
# Real:
#  Tienes usted alguna sugerencia o comentario para mejorar nuestro servicio?
# Es que en este caso no te puedo comentar mucho del servicio ni de la actualización ni de nada, solo de la actualización del perito que ha sido correcta
# Predicción:
# tienes alguna sugerencia un comentario para mejorar nuestro servicio es que en este caso no te puedo comentar mucho del servicio ni de la digolización y de nada sólo de la actualización del perito que ha sido correcta
#
#
# Real:
#  De acuerdo y tiene alguna sugerencia o comentario para mejorar nuestro servicios?
# Nada más
# Predicción:
# de acuerdo y tira una sugerencia o comentario para mejorar nuestros servicios no tomás
#
#
# Real:
#  Bien tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# No, no
# Predicción:
# bien tiene alguna sugerencia del comentario para mejorar nuestro servicio no
#
#
# Real:
#  Señora Monica tiene alguna sugerencia o comentario para mejorar nuestro servicio a parte de [post] que me ha comentado del perito?
# No a parte de lo que he comentado del perito, no
# De acuerdo
# Predicción:
# señala mónica tiene alguna sugrencias comentario para mejorar de su servicio parte de sistema comentado del son parte de lo que comenta de perito de acuerdo
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar nuestro servicio es decir algun comentario que quiera añadir usted?
# Pues no no tengo ninguno
# Predicción:
# tiene usted alguna sugerencia comentario para mejorar nuestros servicios de algún comentario que quiere añadir usted
#
#
# Real:
#  Hemos finalizado alguna sugerencia, algun comentario para mejorar su servicio que nos quiera hacer llegar, señor Gonzalo?
# Pues no no tengo [ningun] comentario
# Predicción:
# os finalizado tienen una sugerencia comentario para mejorar nuestro servicio y que nos quiere indicar un comentario
#
#
# Real:
#  Tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# No ya esta todo bien
# Predicción:
# tiene alguna sugerencia comentario para mejorar nuestro servicio no y está todo bien
#
#
# Real:
#  Tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# No no yo encantada
# Predicción:
# tiene alguna sugerencia o comentario para mejorar nuestro servicio no lo estoy encantada
#
#
# Real:
#  Tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# He tengo otro ciniestro que me han contenstado telefonicamente y me dicen que en principio no esta cubierto pero me dijeron que me iban a mandar de la misma de la misma
# Predicción:
# tiene alguna sugerencia comentario para mejorar nuestro servicio tengo otro siniestro que en que me han contestado telefónicamente me dicen que en principio no está cubierto pero me dijeron que vivas a matar es de la misma de la misma
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar nuestros servicios es decir alguna cosa que quiera añadir usted señor Portela?
# No
# Predicción:
# tiene usted alguna sugerencia comentario para mejorar nuestros servicios de decir alguna cosa que quiere añadir usa el señor portela
#
#
# Real:
#  Tiene usted alguna sugerencia o comentario para mejorar nuestro servicio?
# No
# No de acuerdo
# Predicción:
# tienes alguna sugerencia o comentario para mejorar nuestro servicio no nada de acuerdo
#
#
# Real:
#  De acuerdo, tiene alguna sugerencia o comentario para mejorar nuestro servicio?
# No ya esta todo muchas gracias
# Predicción:
# acuerda tiene alguna sugerencia comentario para mejorar nuestro servicio no está todo mi caracas
#
#
# Real:
#  Quiere añadir algun comentario más?
# No ya esta todo
# Nada más
# Predicción:
# quiere añadir algún comentario másnada más
#
#
# Real:
#  Tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía?
# No porque todo yo le digo que fue muy bien
# Predicción:
# si no se una lugencia para mejorar los servicios que le presta a la compañía no volver todo o de por muy bien
#
#
# Real:
#  Y tiene alguna sugerencia para mejorar los servicios que le presta la compañía?
# No la verdad es que me ha sido facil rapido y todo
# Predicción:
# y tiene alguna sugerencia para mejorar los servicios que le presta la compañía no los laboratorio fácil y rápido editor
#
#
# Real:
#  Señor Valverde, tienes alguna sugerencia para mejorar los servicios que le presta la compañía?
# No en este caso concreto de este siniestro ya le digo que ha ido todo bastante bien rapido agil
# Predicción:
# el valverde tiene salvo una suferencia para mercarlos fitos que repensar la compañía no en este caso congreso siniestro ya medio caído todo bastante bien rápido ager
#
#
# Real:
#  Quiere añadir algun comentario más?
# No
# Predicción:
# quien añade algún comentario más no
#
#
# Real:
#  Y tiene alguna sugerencia para mejorar los servicios que le presta la compañía?
# Sí
# Digame
# Predicción:
# y tiene alguna sugerencia para mejorar los servicios que le presta la compañía me
#
#
# Real:
#  Tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía?
# No
# Predicción:
# tiene una segunda sugerencia para mejorar los servicios que le presta la compañía
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía aparte de lo que usted ha comentado?
# No
# Predicción:
# tiene alguna surgencia para mejorar los servicios que le presta la compañía parte de lo cuestiona comentado no
#
#
# Real:
#  Tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía?
# No de momento no
# Predicción:
# tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía?
# No ninguna todo bien
# Predicción:
# tiene alguna sugerencia para mejorar el servicio que le presta a la compañía
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía[anticarnos??]?
# Este no en principio no
# Predicción:
# tiene alguna sugerencia para mejorar los servicios que le presta la compañía anti carnos
#
#
# Real:
#  Y tiene alguna sugerencia para mejorar los servicios que le presta la compañía?
# No no no no
# Predicción:
# y tiene alguna sugerencia para mejorar los servicios que le presta a la compañía
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía que me quiera indicar?
# Es que a mí me ha ido todo fenomenal ha sido todo muy rapido todo muy sencillo y no he tenido ningun problema
# Predicción:
# tiene una sugerencia para no parar servicios crepes par la compañía que me quiere indicar es que ni mediatos nominal acido muy rápido y son muy sencillo y no tenía ningún problema
#
#
# Real:
#  Pues tienes alguna sugerencia para mejorar los servicios que le presta la compañía?
# Pues no, la verdad que no en este momento no
# Predicción:
# pues que nos haz una diferencia para mejor los retos que presta a la compañía no nada la que no no
#
#
# Real:
#  tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía?
# De momento no
# Predicción:
# que no sabe una sugerencia para mejorar el servicio que le presta la compañía de momento no
#
#
# Real:
#  Muy bien quiere añadir algun comentario más?
# No
# Predicción:
# muy bien quiere añadir algún comentario más
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía?
# Pues no se me ocurre nada
# Predicción:
# tiene alguna sugrencias para enojar los servicios que le presta la compañía
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía que nos quiera indicar?
# No
# Predicción:
# nos pidan una sugerencia para mejorar los servicios que le pesa la compañía que no estira indicar lo
#
#
# Real:
#  Tiene alguna sugerencia para mejorar los servicios que le presta la compañía?
# Bueno algunas veces que pongan más claro
# Predicción:
# pues tions alguna sugerencia para mejorar los picos que le presta la compañía bueno algunas deseque ponga más claro
#
#
# Real:
#  Y tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía?
# No
# Predicción:
# si tiene usted alguna sugerencia para mejorar los servicios que le presta la compañía
#
#
# Real:
#  Tiene usted alguna sugerencia [Señor Halcon?] para mejorar los servicios que le presta la compañía?
# Pues no de momento nada lo unico que tuve una incidencia en su dia con el primer parte que tuve
# Si
# Predicción:
# tienes algunas sugerencias en arconte para mejorar los servicios que le presta la compañía no el momento nada lo único que tuvo una incidencia en su vida con con el primer parte que tuve si

# %%
total
# Out:
#                                           AUDIOS  \
# 0       CAT_AGB-CR[13-(004574CS)]_20220325172808
# 1       CAT_AGB-CR[435-(9225972)]_20220325172537
# 2       CAT_AGB-CR[807-(150876H)]_20220325172741
# 3      CAT_AGB-CR[1084-(9634312)]_20220325172650
# 4      CAT_AGB-CR[1218-(9930617)]_20220325172944
# 5     CAT_AGB-CR[1269-(042420SB)]_20220325172710
# 6  CAT-EPS-SATS[7431-(302307602)]_20220325170449
# 7  CAT-MDP-SIN[7820-(1000121072)]_20220325171609
#
#                                             CORRECIÓ  \
# 0  I perque ha decidit ferla a traves del servei ...
# 1  I desitja realitzar alguna suggerencia que ens...
# 2  I vol afegir algún comentari més apart de lo q...
# 3  Desitja realitzar-nos algun sugeriment que ens...
# 4  Desitja realitzar-nos algun sugeriment que ens...
# 5  Vol afegir alguna sugerencia que ens ajudi a m...
# 6  Val d'acord, i té algún suggeriment, comentari...
# 7  D'acord doncs per últim té algun suggeriment o...
#
#                                        transcripcion
# 0  i per què ha preferit fer-la a través del serv...
# 1  i de ha realitzat alguna suggerència que ens a...
# 2  i vol afegir algun comentari més a part del qu...
# 3  de fet a realitzar nos algun suggeriment que e...
# 4  dineralitzar-nos alguna suggerència que ens aj...
# 5  vol afegir alguna suggerència que ens ajudi a ...
# 6  d'acord té algun suggeriment comentari per mil...
# 7  d'acord parin suggeriment comentari per millor...

# %%
r.loc[:,['AUDIOS','transcripcion']]
# Out:
#                                           AUDIOS  \
# 0      CAT_AGB-CR[1218-(9930617)]_20220325172944
# 1     CAT_AGB-CR[1269-(042420SB)]_20220325172710
# 2       CAT_AGB-CR[435-(9225972)]_20220325172537
# 3      CAT_AGB-CR[1084-(9634312)]_20220325172650
# 4       CAT_AGB-CR[807-(150876H)]_20220325172741
# 5       CAT_AGB-CR[13-(004574CS)]_20220325172808
# 6  CAT-EPS-SATS[7431-(302307602)]_20220325170449
# 7  CAT-MDP-SIN[7820-(1000121072)]_20220325171609
#
#                                        transcripcion
# 0  dineralitzar-nos alguna suggerència que ens aj...
# 1  vol afegir alguna suggerència que ens ajudi a ...
# 2  i de ha realitzat alguna suggerència que ens a...
# 3  de fet a realitzar nos algun suggeriment que e...
# 4  i vol afegir algun comentari més a part del qu...
# 5  i per què ha preferit fer-la a través del serv...
# 6  d'acord té algun suggeriment comentari per mil...
# 7  d'acord parin suggeriment comentari per millor...
